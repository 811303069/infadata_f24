# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/khush/Downloads/cces_example_data.csv")
df.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].set_title("Age Histogram")
ax[1].set_title("Political Identity")

plt.show()

# %%
evaluation_counts = df['Evaluation'].value_counts()
evaluation_counts.plot(kind='bar', figsize=(8, 6))

plt.title('Frequencies of Responses in Evaluation')
plt.xlabel('Evaluation Categories')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['ConMediaUse'], df['ImmiPhobia'], alpha=0.5)
plt.title('ConMediaUse vs ImmiPhobia')
plt.xlabel('ConMediaUse')
plt.ylabel('ImmiPhobia')

plt.show()

# %% [markdown]
# To improve the scatter plot between ConMediaUse and ImmiPhobia, here are some easy ways to make it clearer and more informative:
# 1. Use Color Coding
# Sort the points by color according to pid3 (political identity). This illustrates the ways in which various political factions view immigration and use the media.
# 2. Add Transparency
# If there is a lot of overlap between the points, the density of the data can be seen by slightly transparent (alpha) points, which allows us to see where the majority of the responses are concentrated.
# 3. Add a Trend Line
# Adding a line that shows the general trend of the data helps identify if there’s a relationship between the two variables, like whether higher media use links to more immigration fear.
# 4. Improve Labels
# To make it easy for people to understand what the data is showing, make sure the axes are labeled correctly and the plot has clear titles.
# 5. Use Gridlines and Good Markers
# Light gridlines can help people read the plot better. Also, using appropriate shapes or sizes for the data points can make the plot easier to look at.
